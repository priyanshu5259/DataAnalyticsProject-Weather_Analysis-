# %%
import pandas as pd

# %%
data = pd.read_csv(r"/content/file.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# Q1.Find all the unique 'Wind Speed' values in the data
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
data['Wind Speed_km/h'].nunique() #answer
# Out:
# 34

# %%
# Q2.Find the number of times when the 'Weather is exactly clear'
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data.Weather=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# Q3. Find the no. of times when the 'Wind speed was exctly 4km/h'
data[data['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
#Q4. Find out all the NULL Values in the data
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
#Q5. Rename the column name 'Weather' of the dataframe to 'Weather condition'
data.rename(columns={'Weather':'Weather Condition'}) #Here the column name is renamed temporarily
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns={'Weather':'Weather Condition'},inplace=True)#from this the weather is renamed to weather condition permanently

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
#Q6.What is the mean Visbility
data.Visibility_km.mean()
# Out:
# 27.664446721311478

# %%
#Q7. What is the Standard Deviation of 'Pressure' in the data
data.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
#Q8. What is the Variance of 'Relative Humidity' in this data
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
#Q9. Find all instances when 'Snow' was recorded
data['Weather Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather Condition']=='Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[data['Weather Condition'].str.contains('Snow')] #used for partial match
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Q10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'
data[(data['Wind Speed_km/h']>24)  & (data['Visibility_km']==25 )]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
#Q11. What is the mean value of eaach column against each 'Weather Condition'
data.groupby('Weather Condition').mean()
# Out:
# <ipython-input-59-4ac801d6f442>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Weather Condition').mean()
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# ...

# %%
#Q12. What is the minimum and maximum value of each column against each 'Weather Condition'
data.groupby('Weather Condition').max()
data.groupby('Weather Condition').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
#Q12. Show all the records of the weather condition is fog
data[data['Weather Condition']=='Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
#Q14. Find all instances when 'Weather is Clear 'or 'Visibility is above 40'
data[(data['Weather Condition']=='Clear') | (data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
#Q15. Find all the instances when weather is clear and relative humidity is greater than 50 or visibility is above 40
data[(data['Weather Condition']=='Clear') & (data['Rel Hum_%']>50) | (data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
#Machine Learning
#The thing is that predicting is not good if the data holds any missing value so we need to clean the data
import pandas as pd
data = pd.read_csv(r"/content/file.csv",index_col='Date/Time')

# %%
data.apply(pd.isnull).sum() #this gives the no. of null values in each column
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.apply(pd.isnull).sum()/data.shape[0] #this gives the percentage of null values
# Out:
# Date/Time           0.0
# Temp_C              0.0
# Dew Point Temp_C    0.0
# Rel Hum_%           0.0
# Wind Speed_km/h     0.0
# Visibility_km       0.0
# Press_kPa           0.0
# Weather             0.0
# dtype: float64

# %%
#suppose if we need to eliminate some columns because they are not contributing in the core value of dataset yhen we will use
#core_data=data[["Date/Time","Temp_C","Rel Hum_%","Press_kPa"]].copy
#core_data.columns=["date","temp","humidity","pressure"] we have renamed the column names
#as here there is no such requirements so we can take the original data only

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.index=pd.to_datetime(data.index)

# %%
data.index
# Out:
# DatetimeIndex([          '1970-01-01 00:00:00',
#                '1970-01-01 00:00:00.000000001',
#                '1970-01-01 00:00:00.000000002',
#                '1970-01-01 00:00:00.000000003',
#                '1970-01-01 00:00:00.000000004',
#                '1970-01-01 00:00:00.000000005',
#                '1970-01-01 00:00:00.000000006',
#                '1970-01-01 00:00:00.000000007',
#                '1970-01-01 00:00:00.000000008',
#                '1970-01-01 00:00:00.000000009',
#                ...
#                '1970-01-01 00:00:00.000008774',
#                '1970-01-01 00:00:00.000008775',
#                '1970-01-01 00:00:00.000008776',
#                '1970-01-01 00:00:00.000008777',
#                '1970-01-01 00:00:00.000008778',
#                '1970-01-01 00:00:00.000008779',
#                '1970-01-01 00:00:00.000008780',
#                '1970-01-01 00:00:00.000008781',
#                '1970-01-01 00:00:00.000008782',
# ...

# %%
#by doing this we can get the sybset of date that is year alone
data.index.year
# Out:
# Int64Index([2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012,
#             ...
#             2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012],
#            dtype='int64', name='Date/Time', length=8784)

# %%
data[["Temp_C"]].plot()
# Out:
# <Axes: xlabel='Date/Time'>

# %%
#We need to predict the temperature of tommorrow by using the temperature of today
data["target"]=data.shift(-1)["Temp_C"]  #By using this we have made temp to shift up

# %%
data
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
# 2012-12-31 23:00:00     0.0              -2.1         86               30
#
# ...

# %%
data=data.iloc[:-1,:].copy()

# %%
data
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 18:00:00    -1.3              -3.1         88               17
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
#
# ...

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)

# %%
predictors=["Temp_C","Dew Point Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Press_kPa"]

# %%
train=data.loc[:"2012-11-30"]

# %%
test=data.loc["2012-12-01":]

# %%
reg.fit(train[predictors],train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test["target"],predictions)
# Out:
# 0.5409896176634839

# %%
combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)

# %%
combined
# Out:
#                      target          0
# Date/Time
# 2012-12-01 00:00:00   -11.0 -10.640464
# 2012-12-01 01:00:00   -11.1 -10.855354
# 2012-12-01 02:00:00   -12.5 -10.990309
# 2012-12-01 03:00:00   -11.8 -12.047970
# 2012-12-01 04:00:00   -11.9 -11.390666
# ...                     ...        ...
# 2012-12-31 18:00:00     0.1  -1.411073
# 2012-12-31 19:00:00     0.2  -0.251165
# 2012-12-31 20:00:00    -0.5  -0.083663
# 2012-12-31 21:00:00    -0.2  -0.725750
# 2012-12-31 22:00:00     0.0  -0.366248
#
# [743 rows x 2 columns]

# %%
combined.columns=["actual","predictions"]

# %%
combined
# Out:
#                      actual  predictions
# Date/Time
# 2012-12-01 00:00:00   -11.0   -10.640464
# 2012-12-01 01:00:00   -11.1   -10.855354
# 2012-12-01 02:00:00   -12.5   -10.990309
# 2012-12-01 03:00:00   -11.8   -12.047970
# 2012-12-01 04:00:00   -11.9   -11.390666
# ...                     ...          ...
# 2012-12-31 18:00:00     0.1    -1.411073
# 2012-12-31 19:00:00     0.2    -0.251165
# 2012-12-31 20:00:00    -0.5    -0.083663
# 2012-12-31 21:00:00    -0.2    -0.725750
# 2012-12-31 22:00:00     0.0    -0.366248
#
# [743 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date/Time'>

# %%
reg.coef_
# Out:
# array([ 1.01171429, -0.01923185,  0.02673655, -0.00438669,  0.03270237,
#         0.0769364 ])

# %%
def create_predictions(predictions,data,reg):
  train=data.loc[:"2012-11-30"]
  test=data.loc["2012-12-01":]
  reg.fit(train[predictors],train["target"])
  predictions=reg.predict(test[predictors])
  error=mean_absolute_error(test["target"],predictions)
  combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)
  combined.columns=["actual","predictions"]
  return error,combined

# %%
data["month_max"]=data["Temp_C"].rolling(30).mean()

# %%
data
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 18:00:00    -1.3              -3.1         88               17
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
#
# ...
